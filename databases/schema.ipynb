# %% [markdown]
# # Database SCHEMA for BuSy

# %% [markdown]
# ```sql
# CREATE TABLE "users" (
# 	"id"	INTEGER NOT NULL UNIQUE,
# 	"user_type"	INTEGER NOT NULL,
# 	"username"	VARCHAR NOT NULL,
# 	"fullname"	TEXT NOT NULL,
# 	"cellphone"	INTEGER,
# 	"email"	TEXT,
# 	"birthday"	DATETIME,
# 	"rfc"	VARCHAR,
# 	"password"	VARCHAR NOT NULL,
# 	PRIMARY KEY("id"),
# 	FOREIGN KEY("user_type") REFERENCES "user_type"("id") ON UPDATE NO ACTION ON DELETE NO ACTION
# );
#
# CREATE INDEX IF NOT EXISTS "users_index_0"
# ON "users" ();
#
# CREATE TABLE IF NOT EXISTS "user_type" (
# 	"id" INTEGER NOT NULL UNIQUE,
# 	"type" INTEGER,
# 	PRIMARY KEY("id")
# );
#
# CREATE TABLE IF NOT EXISTS "info_db" (
# 	"id" INTEGER NOT NULL UNIQUE,
# 	"info" VARCHAR,
# 	PRIMARY KEY("id")
# );
# ```

# %% [markdown]
# ## Initialice DB

# %% [markdown]
# Lo primero: Crear la base de datos.
#
# - Inicializo por primera vez el objeto y la base de datos se crea en automático

# %%
from singleton import Database

db: Database = Database()
# Out:
# Conexión a la base de datos establecida en: /Users/josueernestogalindomorales/Desktop/systems/BuSy/databases/systemDB.db
